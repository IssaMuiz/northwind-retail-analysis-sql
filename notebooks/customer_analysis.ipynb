# %%
from sqlalchemy import create_engine, text
import pandas as pd

engine = create_engine("mysql+pymysql://root:Muiztun1#@127.0.0.1/northwind")

with open("../sql/customer_analysis.sql", "r") as f:
    query = f.read()

with engine.connect() as conn:
    result = conn.execute(text(query))

    df = pd.DataFrame(result)

df
# Out:
#     customer_id     company first_name     last_name   total_revenue
# 0            28  Company BB  Amritansh        Raghav  15432.50000000
# 1             7   Company G  Ming-Yang           Xie  13800.00000000
# 2             6   Company F  Francisco  Pérez-Olaeta   8007.50000000
# 3             4   Company D  Christina           Lee   4949.00000000
# 4             8   Company H  Elizabeth      Andersen   4683.00000000
# 5             9   Company I       Sven     Mortensen   3786.50000000
# 6            26   Company Z        Run           Liu   3625.25000000
# 7            29  Company CC   Soo Jung           Lee   2905.50000000
# 8             3   Company C     Thomas          Axen   2550.00000000
# 9             1   Company A       Anna        Bedecs   2410.75000000
# 10           27  Company AA      Karen           Toh   1505.00000000
# 11           10   Company J     Roland        Wacker   1412.50000000
# 12           12   Company L       John       Edwards   1190.00000000
# 13           11   Company K      Peter       Krschne   1019.50000000
# 14           25   Company Y       John        Rodman    860.00000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    15 non-null     int64
#  1   company        15 non-null     object
#  2   first_name     15 non-null     object
#  3   last_name      15 non-null     object
#  4   total_revenue  15 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 728.0+ bytes

# %%
df.columns
# Out:
# Index(['customer_id', 'company', 'first_name', 'last_name', 'total_revenue'], dtype='object')
